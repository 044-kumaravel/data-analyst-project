# %%
import pandas as pd
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
    ('customers.csv', 'customers'),
    ('orders.csv', 'orders'),
    ('order_items.csv', 'order_items'),
    ('products.csv', 'products'),
    ('geolocation.csv', 'geolocation'),
    ('payments.csv', 'payments') ,
    ('sellers.csv','sellers')# Added payments.csv for specific handling
]

# Connect to the MySQL database
conn = mysql.connector.connect(
    host='127.0.0.1',
    user='root',
    password='3306',
    database='mykuar'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = 'C:/Users/ELCOT/Desktop/ecommerce'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Replace NaN with None to handle SQL NULL
    df = df.where(pd.notnull(df), None)
    
    # Debugging: Check for NaN values
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    # Clean column names
    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    # Generate the CREATE TABLE statement with appropriate data types
    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)

    # Insert DataFrame data into the MySQL table
    for _, row in df.iterrows():
        # Convert row to tuple and handle NaN/None explicitly
        values = tuple(None if pd.isna(x) else x for x in row)
        sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(row))})"
        cursor.execute(sql, values)

    # Commit the transaction for the current CSV file
    conn.commit()

# Close the connection
conn.close()
# Out:
# Processing customers.csv
# NaN values before replacement:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Processing orders.csv
# NaN values before replacement:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# Processing order_items.csv
# NaN values before replacement:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Processing products.csv
# NaN values before replacement:
# product_id                      0
# ...

# %%
import pandas as pd 
import seaborn as sb
import matplotlib.pyplot as sns
import mysql.connector

db=mysql.connector.connect(host="127.0.0.1",
                           username="root",
                           password="3306",
                           database="mykuar")
cursor=db.cursor()

# %% [markdown]
# list all unique cities where customer are located

# %%
line="""select distinct customer_city from customers """
cursor.execute(line)
data=cursor.fetchall()
dd=pd.DataFrame(data ,columns=["names"])
dd
# Out:
#                       names
# 0                    franca
# 1     sao bernardo do campo
# 2                 sao paulo
# 3           mogi das cruzes
# 4                  campinas
# ...                     ...
# 4114                 siriji
# 4115    natividade da serra
# 4116           monte bonito
# 4117             sao rafael
# 4118      eugenio de castro
#
# [4119 rows x 1 columns]

# %% [markdown]
# count the number of order placed in 2017

# %%
line="""select count(order_id) as order_placed from mykuar.orders where order_purchase_timestamp>=2017"""
cursor.execute(line)
data=cursor.fetchall()
"total order placed in ",data[0][0]
# Out:
# ('total order placed in ', 495560)

# %% [markdown]
# find the total sales per category

# %%
line="""select products.product_category,sum(payments.payment_value) from products join order_items on products.product_id=order_items.product_id 
join payments on order_items.order_id=payments.order_id group by products.product_category
"""
cursor.execute(line)
data=cursor.fetchall()
dd=pd.DataFrame(data,columns=["category","total sales"])
dd
# Out:
#                        category   total sales
# 0                     perfumery  5.067387e+07
# 1          Furniture Decoration  1.430176e+08
# 2                     telephony  4.868821e+07
# 3                bed table bath  1.712554e+08
# 4                    automotive  8.522943e+07
# ..                          ...           ...
# 69               cds music dvds  1.199430e+05
# 70                   La Cuisine  2.913530e+05
# 71  Fashion Children's Clothing  7.856700e+04
# 72                     PC Gamer  2.174430e+05
# 73       insurance and services  3.245100e+04
#
# [74 rows x 2 columns]

# %% [markdown]
# calculate the percentage of order that were paid in installements

# %%
line="""select sum(case when payment_installments >= 1 then 1 
else 0 end)/count(*)*100 from payments """
cursor.execute(line)
data=cursor.fetchall()
dd=pd.DataFrame(data,columns=["percentage of order"])
dd
# Out:
#   percentage of order
# 0             99.9981

# %% [markdown]
# count the number of customer from each state

# %%
line=""" select customer_state, count(customer_state)  from customers group by customer_state"""
cursor.execute(line)
data=cursor.fetchall()
dd=pd.DataFrame(data,columns=["state_name","total_customer"])
dd
# Out:
#    state_name  total_customer
# 0          SP          208730
# 1          SC           18185
# 2          MG           58175
# 3          PR           25225
# 4          RJ           64260
# 5          RS           27330
# 6          PA            4875
# 7          GO           10100
# 8          ES           10165
# 9          BA           16900
# 10         MA            3735
# 11         MS            3575
# 12         CE            6680
# 13         DF           10700
# 14         RN            2425
# 15         PE            8260
# 16         MT            4535
# 17         AM             740
# 18         AP             340
# 19         AL            2065
# 20         RO            1265
# 21         PB            2680
# 22         TO            1400
# 23         PI            2475
# 24         AC             405
# 25         SE            1750
# 26         RR             230

# %% [markdown]
# calculate the number of orders per month in 2018

# %%
line="""select monthname(order_purchase_timestamp) as month_name,count(order_purchase_timestamp)
from orders where order_purchase_timestamp=2018 group by month_name
"""
cursor.execute(line)
data=cursor.fetchall()
dd=pd.DataFrame(data,columns=["month_name","no of orders"])
dd
# Out:
#   month_name  no of orders
# 0       July         31460
# 1     August         32560
# 2   February         33640
# 3       June         30835
# 4      March         36055
# 5    January         36345
# 6        May         34365
# 7      April         34695
# 8  September            80
# 9    October            20

# %% [markdown]
#     average number of product per order group by city

# %%
import os
print(os.listdir())
# Out:
# ['-1.14-windows.xml', '.accessibility.properties', '.arduinoIDE', '.bash_history', '.cache', '.config', '.eclipse', '.gitconfig', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lemminx', '.m2', '.matplotlib', '.p2', '.python_history', '.sts4', '.vscode', '006615.tmp', '249774.tmp', '3D Objects', '642928.tmp', '730730.tmp', '850012.tmp', '974132.tmp', '996247.tmp', 'AppData', 'Application Data', 'arduino-ide-2-3-6.exe', 'cbe.10c8a91c1956f613864', 'cbe.2635546c1956be9a57e', 'cbe.2a3dac1f1956ac924af', 'cbe.555d327f1956a8bccdf', 'cbe.67e272111956acb2ee3', 'cbe.7f0842091956f62d619', 'cbe.ef2c997b1956be6feb0', 'cbe.f08570ed1956a89bcb5', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'eclipse', 'eclipse-workspace', 'Favorites', 'git', 'ia_remove.sh0213.tmp', 'ia_remove.sh3213.tmp', 'ia_remove.sh3219.tmp', 'ia_remove.sh4427.tmp', 'ia_remove.sh4928.tmp', 'ia_remove.sh5870.tmp', 'ia_remove.sh7792.tmp', 'ia_remove.sh9886.tmp', 'InstallAnywhere', 'kumar', 'Links', 'Local
# ...
